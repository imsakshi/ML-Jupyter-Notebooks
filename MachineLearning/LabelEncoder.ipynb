# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import sklearn


from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv("titanic.csv")

# %%
data.columns = ['Survived','Pclass','Name','Sex','Age','Siblings/Spouses Aboard','Siblings/Spouses Aboard','Fare']
data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Siblings/Spouses Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
le = preprocessing.LabelEncoder()


# 2/3. FIT AND TRANSFORM
# use df.apply() to apply le.fit to all columns
X_2 = data.apply(le.fit_transform)
X_2.head()
# Out:
#    Survived  Pclass  Name  Sex  Age  Siblings/Spouses Aboard  \
# 0         0       2   601    1   28                        1
# 1         1       0   822    0   51                        1
# 2         1       2   171    0   34                        0
# 3         1       0   813    0   47                        1
# 4         0       2   732    1   47                        0
#
#    Siblings/Spouses Aboard  Fare
# 0                        0    18
# 1                        0   207
# 2                        0    41
# 3                        0   189
# 4                        0    43
